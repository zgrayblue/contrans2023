# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Bring in the voteview data, and filter to the 118th congress

# %%
ideology = pd.read_csv('https://voteview.com/static/data/out/members/HS118_members.csv')

# %%
ideology['chamber'].value_counts()
# Out:
# chamber
# House     441
# Senate    100
# Name: count, dtype: int64

# %%
ideology[['bioname', 'chamber', 'party_code','state_abbrev', 'district_code','nominate_dim1']]\
    .sort_values("nominate_dim1", ascending=True)
# Out:
#                                bioname chamber  party_code state_abbrev  \
# 382                     GARCIA, Sylvia   House         100           TX
# 482                  WARREN, Elizabeth  Senate         100           MA
# 71                        LEE, Barbara   House         100           CA
# 143                       CASTEN, Sean   House         100           IL
# 66                      WATERS, Maxine   House         100           CA
# ..                                 ...     ...         ...          ...
# 527                          LEE, Mike  Senate         200           UT
# 474                         PAUL, Rand  Senate         200           KY
# 320                     BRECHEEN, Josh   House         200           OK
# 441  TUBERVILLE, Thomas Hawley (Tommy)  Senate         200           AL
# 490              SCHMITT, Eric Stephen  Senate         200           MO
#
#      district_code  nominate_dim1
# 382             29         -0.807
# 482              0         -0.752
# 71              12         -0.677
# 143              6         -0.672
# 66              43         -0.656
# ..             ...            ...
# 527              0          0.891
# 474              0          0.891
# 320              2          0.926
# 441              0          0.936
# 490              0          0.945
#
# [541 rows x 6 columns]

# %%
replace_map = {100: "Democrat", 200: "Republican", 328: "Independent"}
ideology['party_code'] = ideology['party_code'].replace(replace_map)
ideology['party_code'].value_counts()
# Out:
# party_code
# Republican     274
# Democrat       264
# Independent      3
# Name: count, dtype: int64

# %%
ideology.query("party_code == 'Independent'")[['bioname', 'chamber', 'state_abbrev', 'nominate_dim1']]
# Out:
#                       bioname chamber state_abbrev  nominate_dim1
# 446           SINEMA, Kyrsten  Senate           AZ         -0.303
# 477  KING, Angus Stanley, Jr.  Senate           ME         -0.162
# 530          SANDERS, Bernard  Senate           VT         -0.539

# %%
ideology.query("state_abbrev == 'CA' & chamber == 'House'")[['district_code', 'party_code', 'bioname', 'nominate_dim1']]
# Out:
#     district_code  party_code                   bioname  nominate_dim1
# 22             11    Democrat             PELOSI, Nancy         -0.490
# 23             30    Democrat              SCHIFF, Adam         -0.350
# 24             48  Republican             ISSA, Darrell          0.486
# 25             38    Democrat         SÁNCHEZ, Linda T.         -0.508
# 26             21    Democrat                COSTA, Jim         -0.195
# 27              7    Democrat             MATSUI, Doris         -0.435
# 28             20  Republican           MCCARTHY, Kevin          0.458
# 29              5  Republican           McCLINTOCK, Tom          0.685
# 30             28    Democrat                 CHU, Judy         -0.488
# 31              8    Democrat           GARAMENDI, John         -0.309
# 32              1  Republican             LaMALFA, Doug          0.535
# 33              2    Democrat            HUFFMAN, Jared         -0.430
# 34              6    Democrat                 BERA, Ami         -0.239
# 35             14    Democrat            SWALWELL, Eric         -0.362
# 36             22  Republican         VALADAO, David G.          0.261
# 37             26    Democrat           BROWNLEY, Julia         -0.291
# 38             29    Democrat            CÁRDENAS, Tony         -0.390
# 39             25    Democrat                RUIZ, Raul         -0.249
# 40             39    Democrat              TAKANO, Mark         -0.464
# 41             52    Democrat              VARGAS, Juan         -0.403
# 42             50    Democrat             PETERS, Scott         -0.187
# 43             10    Democrat    DESAULNIER, Mark James         -0.526
# 44             33    Democrat        AGUILAR, Peter Rey         -0.304
# 45             36    Democrat                 LIEU, Ted         -0.378
# 46             35    Democrat      TORRES, Norma Judith         -0.363
# 47             44    Democrat    BARRAGÁN, Nanette Diaz         -0.513
# 48             24    Democrat           CARBAJAL, Salud         -0.304
# 49             46    Democrat         CORREA, Jose Luis         -0.285
# 50             17    Democrat             KHANNA, Rohit         -0.506
# 51             19    Democrat      PANETTA, James Varni         -0.290
# 52             34    Democrat              GOMEZ, Jimmy         -0.555
# 53              9    Democrat              HARDER, Josh         -0.362
# 54             49    Democrat               LEVIN, Mike         -0.360
# 55             47    Democrat             PORTER, Katie         -0.213
# 56             27  Republican              GARCIA, Mike          0.384
# 57             51    Democrat              JACOBS, Sara         -0.353
# 58             40  Republican                KIM, Young          0.266
# 59             23  Republican            OBERNOLTE, Jay          0.311
# 60             45  Republican           STEEL, Michelle          0.356
# 61             13  Republican              DUARTE, John          0.353
# 62             42    Democrat            GARCIA, Robert         -0.445
# 63             37    Democrat     KAMLAGER-DOVE, Sydney         -0.600
# 64              3  Republican              KILEY, Kevin          0.279
# 65             15    Democrat             MULLIN, Kevin         -0.560
# 66             43    Democrat            WATERS, Maxine         -0.656
# 67             16    Democrat       ESHOO, Anna Georges         -0.380
# 68             41  Republican              CALVERT, Ken          0.345
# 69             18    Democrat              LOFGREN, Zoe         -0.400
# 70             32    Democrat             SHERMAN, Brad         -0.344
# 71             12    Democrat              LEE, Barbara         -0.677
# 72              4    Democrat         THOMPSON, Michael         -0.393
# 73             31    Democrat  NAPOLITANO, Grace Flores         -0.448

# %%
url = 'https://voteview.com/static/data/out/votes/HS118_votes.csv'
votes = pd.read_csv(url)
votes
# Out:
#         congress chamber  rollnumber  icpsr  cast_code   prob
# 0            118   House           1  14854          6  100.0
# 1            118   House           1  14863          6   98.0
# 2            118   House           1  14873          1  100.0
# 3            118   House           1  15029          1  100.0
# 4            118   House           1  15433          1  100.0
# ...          ...     ...         ...    ...        ...    ...
# 248232       118  Senate         247  42303          6   91.4
# 248233       118  Senate         247  42304          6   63.7
# 248234       118  Senate         247  49308          1  100.0
# 248235       118  Senate         247  49703          1  100.0
# 248236       118  Senate         247  91300          1  100.0
#
# [248237 rows x 6 columns]

# %%
# First do athe merge in a way that checks for problems
ideology_votes = pd.merge(votes, ideology,
                         on = 'icpsr',
                         how = 'outer',
                         validate = 'many_to_one',
                         indicator = 'matched')

# %%
ideology_votes['matched'].value_counts()
# Out:
# matched
# both          248237
# left_only          0
# right_only         0
# Name: count, dtype: int64

# %%
# Second if the checks all pass, merge in a way that is more memory efficient
ideology_votes = pd.merge(votes, ideology,
                         on = 'icpsr',
                         how = 'inner'
                         )

# %%
ideology_votes
# Out:
#         congress_x chamber_x  rollnumber  icpsr  cast_code   prob  congress_y  \
# 0              118     House           1  14854          6  100.0         118
# 1              118     House           2  14854          6  100.0         118
# 2              118     House           3  14854          6  100.0         118
# 3              118     House           4  14854          6  100.0         118
# 4              118     House           5  14854          6  100.0         118
# ...            ...       ...         ...    ...        ...    ...         ...
# 248232         118    Senate         243  91300          6   99.8         118
# 248233         118    Senate         244  91300          1  100.0         118
# 248234         118    Senate         245  91300          1   99.8         118
# 248235         118    Senate         246  91300          1  100.0         118
# 248236         118    Senate         247  91300          1  100.0         118
#
#        chamber_y  state_icpsr  district_code  ... died nominate_dim1  \
# 0          House           51              5  ...  NaN         0.336
# 1          House           51              5  ...  NaN         0.336
# 2          House           51              5  ...  NaN         0.336
# 3          House           51              5  ...  NaN         0.336
# 4          House           51              5  ...  NaN         0.336
# ...          ...          ...            ...  ...  ...           ...
# 248232    Senate           61              0  ...  NaN        -0.303
# 248233    Senate           61              0  ...  NaN        -0.303
# 248234    Senate           61              0  ...  NaN        -0.303
# 248235    Senate           61              0  ...  NaN        -0.303
# 248236    Senate           61              0  ...  NaN        -0.303
#
#         nominate_dim2  nominate_log_likelihood nominate_geo_mean_probability  \
# 0               0.135                -47.23858                       0.90240
# 1               0.135                -47.23858                       0.90240
# 2               0.135                -47.23858                       0.90240
# 3               0.135                -47.23858                       0.90240
# 4               0.135                -47.23858                       0.90240
# ...               ...                      ...                           ...
# 248232          0.532                -18.40028                       0.92375
# 248233          0.532                -18.40028                       0.92375
# 248234          0.532                -18.40028                       0.92375
# 248235          0.532                -18.40028                       0.92375
# 248236          0.532                -18.40028                       0.92375
#
#        nominate_number_of_votes  nominate_number_of_errors  conditional  \
# 0                           460                         10          NaN
# 1                           460                         10          NaN
# 2                           460                         10          NaN
# 3                           460                         10          NaN
# 4                           460                         10          NaN
# ...                         ...                        ...          ...
# 248232                      232                          7          NaN
# 248233                      232                          7          NaN
# 248234                      232                          7          NaN
# 248235                      232                          7          NaN
# 248236                      232                          7          NaN
#
#         nokken_poole_dim1  nokken_poole_dim2
# 0                   0.365              0.754
# 1                   0.365              0.754
# 2                   0.365              0.754
# 3                   0.365              0.754
# 4                   0.365              0.754
# ...                   ...                ...
# 248232             -0.303              0.532
# 248233             -0.303              0.532
# 248234             -0.303              0.532
# 248235             -0.303              0.532
# 248236             -0.303              0.532
#
# [248237 rows x 27 columns]
